# %%
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
import time

# %%
model_id = "dreamlike-art/dreamlike-diffusion-1.0"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
prompt = "cutest baby cow ive seen in my head all day and just enjoy destiny for what it is"

# %%
start_time = time.time()
image = pipe(prompt).images[0]
end_time = time.time()
generation_time = end_time - start_time
minutes, seconds = divmod(generation_time, 60)

print("Generation Time: {:.0f} m {:.2f} s".format(minutes, seconds))


print("[PROMPT]: ",prompt)
plt.imshow(image)
plt.axis('off')
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generation Time: 197.46 seconds
# [PROMPT]:  cutest baby cow ive seen in my head all day and just enjoy destiny for what it is
# (-0.5, 639.5, 639.5, -0.5)
